# %%
2+2
# Out:
# 4

# %%
print('hello world')
# Out:
# hello world

# %%
def f(x,y):
    return x+y

# %%
f(4,5)
# Out:
# 9

# %% [markdown]
# $$
# \int_{\infty}^{\infty} e^x dx
# $$

# %%
import matplotlib.pylab as py

# %%
py.plot([1,2,3],[2,3,2])
